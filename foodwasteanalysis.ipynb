# %%
import pandas as pd

# %%
# !ls
# Out:
# foodwaste.csv  piechart.png  sample_data

# %%
data = pd.read_csv('foodwaste.csv')

# %%
data.head()
# Out:
#   LOCATION      Country   CAT  ...       Value Flag Codes Flags
# 0      DNK      Denmark  FLFW  ...  110000.000        NaN   NaN
# 1      DNK      Denmark  FLFW  ...  541000.000        NaN   NaN
# 2      DNK      Denmark  FLFW  ...      19.746        NaN   NaN
# 3      NLD  Netherlands  FLFW  ...      10.000        NaN   NaN
# 4      NLD  Netherlands  FLFW  ...      12.500        NaN   NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# # Types of waste

# %%
data['Activity'].value_counts().index
# Out:
# Index(['Households',
#        'Combined: Eurostat proxy for manufacturing of food products - includes tobacco',
#        'Agricultural production', 'Combined: Eurostat proxy for services',
#        'Combined : Post-production and Pre-consumption', 'Total',
#        'Wholesale & Retail', 'Retail', 'Combined : pre-retail',
#        'Food Industry', 'Restaurants',
#        'Combined: Households and food services activities',
#        'Combined: Retail + food services + households', 'Food Services',
#        'Contextual data', 'Combined: food service to households',
#        'Municipal Waste', 'Wholesale', 'School cantines',
#        'Combined : Post-production', 'Combined: Pre-consumption',
#        'Combined: Retail and Food services', 'Grocery stores', 'Producers',
#        'Combined: retail to households', 'Manufacturing of Food products',
#        'Industrial kitchens', 'Large scale consumers', 'Combined', 'Trade',
#        'Transportation', 'Storage', 'Large restaurants',
# ...

# %%
data.loc[data['Activity']==('Restaurants')]
# Out:
#     LOCATION                       Country   CAT  ...       Value Flag Codes Flags
# 692      JPN                         Japan  FLFW  ...      3.6000        NaN   NaN
# 693      JPN                         Japan  FLFW  ...      3.3000        NaN   NaN
# 694      JPN                         Japan  FLFW  ...      3.2000        NaN   NaN
# 695      JPN                         Japan  FLFW  ...      3.1000        NaN   NaN
# 696      JPN                         Japan  FLFW  ...      3.2000        NaN   NaN
# 697      SWE                        Sweden  FLFW  ...  99000.0000        NaN   NaN
# 698      SWE                        Sweden  FLFW  ...     10.0000        NaN   NaN
# 699      SWE                        Sweden  FLFW  ...     10.5560        NaN   NaN
# 700      CHN  China (People's Republic of)  FLFW  ...     19.0000        NaN   NaN
# 701      CHN  China (People's Republic of)  FLFW  ...      1.9000        NaN   NaN
# ...

# %%
x=data.groupby("Country")

# %%
x.first()
# Out:
#                              LOCATION   CAT  ... Flag Codes Flags
# Country                                      ...
# Australia                         AUS  FLFW  ...        NaN   NaN
# Austria                           AUT   WIG  ...        NaN   NaN
# Belgium                           BEL  FLFW  ...        NaN   NaN
# Canada                            CAN  FLFW  ...        NaN   NaN
# China (People's Republic of)      CHN  FLFW  ...        NaN   NaN
# Czech Republic                    CZE   WIG  ...        NaN   NaN
# Denmark                           DNK  FLFW  ...        NaN   NaN
# Estonia                           EST   WIG  ...        NaN   NaN
# Finland                           FIN   WIG  ...        NaN   NaN
# France                            FRA   WIG  ...        NaN   NaN
# Germany                           DEU   WIG  ...        NaN   NaN
# Greece                            GRC   WIG  ...        NaN   NaN
# ...

# %%
x.get_group("Denmark")["Value"].sum()
# Out:
# 7271119.7787

# %%
l=[]
for  cntry in set(data["Country"]):
  l.append(x.get_group(cntry)["Value"].sum())

# %%
l
# Out:
# [7271119.7787,
#  36487656.78639607,
#  132827396.29915664,
#  84909628.81613693,
#  11472725.771442343,
#  518893171.1536585,
#  560419881.7445686,
#  75370587.0,
#  435700.0,
#  4817149.0,
#  74280702.8767647,
#  251000.0,
#  7551929.370000001,
#  62375957.84900001,
#  115841890.28499986,
#  86666152.48359999,
#  37887195.0,
#  4589162.0,
#  164964.0,
#  426754.0,
#  4775511.0,
#  31658216.0,
#  1680566.0,
#  4736618.552000001,
#  16908877.0,
#  7595400.0,
#  8480207.201190474,
#  65694572.25,
#  120017080.9,
#  25686906.0,
#  6924223.0,
#  63122842.021]

# %% [markdown]
# # Waste per country and total cost

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs =list(set(data["Country"]))
students =l
ax.pie(students, labels = langs,radius=2)
plt.show()


x =list(set(data["Country"]))
y = l
# colors = ['yellowgreen','red','gold','lightskyblue','white','lightcoral','blue','pink', 'darkgreen','yellow','grey','violet','magenta','cyan']
porcent =y

patches, texts = plt.pie(y, startangle=90, radius=3)
labels = ['{0} - {1:1.2f}'.format(i,j) for i,j in zip(x, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='left center', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)

plt.savefig('piechart.png', bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Unrecognized location 'left center'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
data['Activity'].value_counts().index
# Out:
# Index(['Households',
#        'Combined: Eurostat proxy for manufacturing of food products - includes tobacco',
#        'Agricultural production', 'Combined: Eurostat proxy for services',
#        'Combined : Post-production and Pre-consumption', 'Total',
#        'Wholesale & Retail', 'Retail', 'Combined : pre-retail',
#        'Food Industry', 'Restaurants',
#        'Combined: Households and food services activities',
#        'Combined: Retail + food services + households', 'Food Services',
#        'Contextual data', 'Combined: food service to households',
#        'Municipal Waste', 'Wholesale', 'School cantines',
#        'Combined : Post-production', 'Combined: Pre-consumption',
#        'Combined: Retail and Food services', 'Grocery stores', 'Producers',
#        'Combined: retail to households', 'Manufacturing of Food products',
#        'Industrial kitchens', 'Large scale consumers', 'Combined', 'Trade',
#        'Transportation', 'Storage', 'Large restaurants',
# ...

# %%
data_activity=data.loc[data["Activity"]=="Households"]

# %%
data_activity.head()
# Out:
#     LOCATION         Country   CAT  ...  Value Flag Codes Flags
# 738      GBR  United Kingdom   OTH  ...   2.40        NaN   NaN
# 739      AUS       Australia  FLFW  ...  28.00        NaN   NaN
# 740      AUS       Australia  FLFW  ...  19.00        NaN   NaN
# 741      AUS       Australia  FLFW  ...   9.31        NaN   NaN
# 742      AUS       Australia  FLFW  ...  44.00        NaN   NaN
#
# [5 rows x 17 columns]

# %%
data_activity_grouped_cntry=data_activity.groupby("Country")

# %%
l_household=[]
for  cntry in set(data_activity["Country"]):
  l_household.append(data_activity_grouped_cntry.get_group(cntry)["Value"].sum())

# %%
l_household
# Out:
# [80023435.29915664,
#  1525656.0,
#  477911.1468960679,
#  50408645.2,
#  3942118.051542342,
#  120550154.75365853,
#  35515036.5324347,
#  254289.0,
#  971114.0,
#  244.53,
#  251000.0,
#  1726415.288919668,
#  6436766.959000001,
#  677030.2849998572,
#  7.3,
#  3672569.0,
#  412795.0,
#  11038.0,
#  329400.0,
#  591887.0,
#  7945389.0,
#  112185.0,
#  4086799.0,
#  903476.0,
#  1548769.0,
#  385734.20119047305,
#  16562300.0,
#  38742946.0,
#  16499640.0,
#  804310.0]

# %%
data_activity["Country"]
# Out:
# 738     United Kingdom
# 739          Australia
# 740          Australia
# 741          Australia
# 742          Australia
#              ...
# 1677     United States
# 1678     United States
# 1679     United States
# 1680     United States
# 1681     United States
# Name: Country, Length: 944, dtype: object

# %% [markdown]
# # HouseHold waste by each country

# %%
# from matplotlib import pyplot as plt
# import numpy as np
# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
# ax.axis('equal')
# langs =list(set(data_activity["Country"]))
# students =l_household
# ax.pie(students, labels = langs)
# plt.show()


import matplotlib.pyplot as plt
import numpy as np

x =list(set(data_activity["Country"]))
y = l_household
# colors = ['yellowgreen','red','gold','lightskyblue','white','lightcoral','blue','pink', 'darkgreen','yellow','grey','violet','magenta','cyan']
porcent =y

patches, texts = plt.pie(y, startangle=90, radius=3)
labels = ['{0} - {1:1.2f}'.format(i,j) for i,j in zip(x, porcent)]

sort_legend = True
if sort_legend:
    patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                          key=lambda x: x[2],
                                          reverse=True))

plt.legend(patches, labels, loc='left center', bbox_to_anchor=(-0.1, 1.),
           fontsize=8)

plt.savefig('piechart.png', bbox_inches='tight')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Unrecognized location 'left center'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
data_activity_lr=data.loc[data["Activity"]=="Large restaurants"]
data_activity_grouped_lr=data_activity_lr.groupby("Country")
l_household=[]

for  cntry in set(data_activity_lr["Country"]):
  l_household.append(data_activity_grouped_lr.get_group(cntry)["Value"].sum())

from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs =list(set(data_activity_lr["Country"]))
students =l_household
ax.pie(students, labels = langs)
plt.show()

# %%
data.head()
# Out:
#   LOCATION      Country   CAT  ...       Value Flag Codes Flags
# 0      DNK      Denmark  FLFW  ...  110000.000        NaN   NaN
# 1      DNK      Denmark  FLFW  ...  541000.000        NaN   NaN
# 2      DNK      Denmark  FLFW  ...      19.746        NaN   NaN
# 3      NLD  Netherlands  FLFW  ...      10.000        NaN   NaN
# 4      NLD  Netherlands  FLFW  ...      12.500        NaN   NaN
#
# [5 rows x 17 columns]

# %%
df_grouped_on_act=data.groupby(["Activity"])

# %%
df_grouped_on_act.get_group("Households")
# Out:
#      LOCATION         Country   CAT  ...  Value Flag Codes Flags
# 738       GBR  United Kingdom   OTH  ...   2.40        NaN   NaN
# 739       AUS       Australia  FLFW  ...  28.00        NaN   NaN
# 740       AUS       Australia  FLFW  ...  19.00        NaN   NaN
# 741       AUS       Australia  FLFW  ...   9.31        NaN   NaN
# 742       AUS       Australia  FLFW  ...  44.00        NaN   NaN
# ...       ...             ...   ...  ...    ...        ...   ...
# 1677      USA   United States  MAEI  ...  47.00        NaN   NaN
# 1678      USA   United States  MAEI  ...  40.00        NaN   NaN
# 1679      USA   United States  MAEI  ...  12.00        NaN   NaN
# 1680      USA   United States  MAEI  ...  23.00        NaN   NaN
# 1681      USA   United States  MAEI  ...   4.00        NaN   NaN
#
# [944 rows x 17 columns]

# %%
waste_cost=[]
for act in set(data["Activity"]):
  waste_cost.append(df_grouped_on_act.get_group(act)["Value"].sum())

# %%
waste_cost
# Out:
# [16.0,
#  57826469.0,
#  112625.10975541998,
#  60028.620498615,
#  144677729.0,
#  6361000.624016621,
#  395369061.5477983,
#  3.2,
#  91455532.3855,
#  26229.772,
#  12798.645166739901,
#  54430630.89,
#  550005.0,
#  76451.65366648999,
#  18295230.0,
#  1900017.0,
#  182043491.0,
#  10.0,
#  54154402.01860612,
#  39008.158,
#  7700.0,
#  2170.0,
#  99166.83960000002,
#  749842028.4270788,
#  5.5,
#  17711589.25,
#  600.0,
#  242686.59463304386,
#  210640000.0,
#  28.0,
#  33713373.0,
#  23004.128,
#  418.0,
#  135731889.27973694,
#  24816345.49455694]

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs =list(set(data["Activity"]))
students =waste_cost
ax.pie(students, labels = langs)
plt.show()

import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')

# data = pd.read_csv('data.csv')
ids =waste_cost 
ages =list(set(data["Activity"]))



plt.hist(ages, edgecolor='black', log=True)

color = '#fc4f30'

plt.axvline(median_age, color=color, label='Age Median', linewidth=2)

plt.legend()

plt.title('Ages of Respondents')
plt.xlabel('countries')
plt.ylabel('cost')

plt.tight_layout()

plt.show()

# %%
data.shape
# Out:
# (3079, 17)

# %%
data.columns
# Out:
# Index(['LOCATION', 'Country', 'CAT', 'Category', 'ACT', 'Activity', 'UNIT',
#        'Unit', 'VAR', 'Variable', 'SRC', 'Source', 'TIME', 'Time', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
data.head()
# Out:
#   LOCATION      Country   CAT  ...       Value Flag Codes Flags
# 0      DNK      Denmark  FLFW  ...  110000.000        NaN   NaN
# 1      DNK      Denmark  FLFW  ...  541000.000        NaN   NaN
# 2      DNK      Denmark  FLFW  ...      19.746        NaN   NaN
# 3      NLD  Netherlands  FLFW  ...      10.000        NaN   NaN
# 4      NLD  Netherlands  FLFW  ...      12.500        NaN   NaN
#
# [5 rows x 17 columns]

# %%
df=data.drop(columns=["CAT","ACT","VAR","SRC","Source","TIME","Flags"])

# %%
df.shape
# Out:
# (3079, 10)

# %%
df=df.drop(columns=['Flag Codes'])

# %%
df.head()
# Out:
#   LOCATION      Country  ...  Time       Value
# 0      DNK      Denmark  ...  2011  110000.000
# 1      DNK      Denmark  ...  2011  541000.000
# 2      DNK      Denmark  ...  2011      19.746
# 3      NLD  Netherlands  ...  2010      10.000
# 4      NLD  Netherlands  ...  2004      12.500
#
# [5 rows x 9 columns]

# %%
set(df["Unit"])
# Out:
# {'%',
#  'Litres/household',
#  'Local Currency',
#  'Local Currency/capita',
#  'Local Currency/household',
#  'Million EUR',
#  'Million Local Currency',
#  'Million USD',
#  'Million kg',
#  'Million litres',
#  'billion calories',
#  'calories/capita/day',
#  'kg',
#  'kg/capita',
#  'kg/capita/day',
#  'kg/capita/week',
#  'kg/day',
#  'kg/household',
#  'kg/household/week',
#  'kg/week',
#  'people/household',
#  'tonnes',
#  'tonnes/day',
#  'tonnnes'}

# %%
df=df.drop(columns=["UNIT"])

# %%
df_grouped_by_units=df.groupby("Unit")

# %%
df_grouped_by_units.get_group("tonnes/day")
# Out:
#      LOCATION Country  ...  Time Value
# 2963      KOR   Korea  ...  2010  26.5
# 2964      KOR   Korea  ...  2012  12.3
#
# [2 rows x 8 columns]

# %%
df_tonnes=df_grouped_by_units.get_group("tonnes/day")

# %%
df_tonnes.groupby(["Country"])
for x,y in df_tonnes.groupby(["Country"]):
  print(x)
# Out:
# Korea

# %%
df_grouped_by_units.get_group("tonnes/day")["Value"].sum()
# df_tonnes.groupby(["Country"])
# Out:
# 38.8

# %%
for unit in set(data["Unit"]):
  df_on_a_unit=df_grouped_by_units.get_group(unit)
  df_uni_groupedoncnrty=df_on_a_unit.groupby(["Country"])
 
  country_list=[x for x,y in df_uni_groupedoncnrty]
  print(unit+"--------------------------------------")
  cost_list=[]
  for country in country_list:
    print(country,df_uni_groupedoncnrty.get_group(country)["Value"].sum())
    cost_list.append(df_uni_groupedoncnrty.get_group(country)["Value"].sum())
  from matplotlib import pyplot as plt
  import numpy as np
  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  ax.axis('equal')
  langs =country_list
  students =cost_list
  ax.pie(students, labels = langs)
  plt.show()

  x =country_list
  y = cost_list
  # colors = ['yellowgreen','red','gold','lightskyblue','white','lightcoral','blue','pink', 'darkgreen','yellow','grey','violet','magenta','cyan']
  porcent =y

  patches, texts = plt.pie(y, startangle=90, radius=1)
  labels = ['{0} - {1:1.2f}'.format(i,j) for i,j in zip(x, porcent)]

  sort_legend = True
  if sort_legend:
      patches, labels, dummy =  zip(*sorted(zip(patches, labels, y),
                                            key=lambda x: x[2],
                                            reverse=True))

  plt.legend(patches, labels, loc='left center', bbox_to_anchor=(-0.1, 1.),
            fontsize=8)

  plt.savefig('piechart.png', bbox_inches='tight')
# Out:
# Local Currency--------------------------------------
# Australia 5645.0
# United Kingdom 950.0
# Local Currency/capita--------------------------------------
# Australia 1678.0
# Germany 233.7
# Netherlands 135.0
# United States 8445.8
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: MatplotlibDeprecationWarning: Unrecognized location 'left center'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
# billion calories--------------------------------------
# United States 1949.5
# tonnes/day--------------------------------------
# Korea 38.8
# kg/capita--------------------------------------
# Australia 126.0
# Austria 3762.0
# Belgium 504.0
# Canada 244.53
# Czech Republic 285.0
# Denmark 780.7787
# Estonia 1232.0
# Finland 918.0
# France 370.0
# Germany 738.1161369189999
# Greece 1159.0
# ...

# %%
df.head()
# Out:
#   LOCATION      Country  ...  Time       Value
# 0      DNK      Denmark  ...  2011  110000.000
# 1      DNK      Denmark  ...  2011  541000.000
# 2      DNK      Denmark  ...  2011      19.746
# 3      NLD  Netherlands  ...  2010      10.000
# 4      NLD  Netherlands  ...  2004      12.500
#
# [5 rows x 8 columns]
